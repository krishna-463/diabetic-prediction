# %% [markdown]
# import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# importing dataset

# %%
df=pd.read_csv("/content/diabetes.csv")

# %% [markdown]
# no of rows and coloumns of dataset

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# printing some rows of dataset

# %%
df.head(10
        )
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# last rows of dataframe

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.info #first and last 5 rows of dataset
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# statistical values of each coloumn

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# calculating mean for target variable that is for outcome

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# seperating the data and target variable

# %%
X = df.drop(columns = "Outcome", axis=1) # axis 1 for droping a column and 0 for dropping row
Y = df["Outcome"]

# %%
print(X) #we removed the labels
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# importing machine learning libraries

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# <h2>standardising the data</h2>
# it means we are adusting the data in each column to certain value
# example
# the data in column blood pressure of range from 0 to 122
# if we use standardising the range changes from 0 to 2

# %%
s=StandardScaler() #creating an object to StandardScaler class

# %% [markdown]
# let sd standardized data

# %%
s.fit(X)
# Out:
# StandardScaler()

# %%
sd = s.transform(X)

# %%
print(sd) #we can see the data between in small ranges
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %% [markdown]
# assign these standaedised data to x

# %%
X=sd 
Y=Y #no need standardise y

# %% [markdown]
# splitting the test and training data in 80:20%
# >training x data as xt
#  training labeled data as y as yt
#  testing x data as xn
#  testing y data as yn

# %% [markdown]
# <h1><b>stratify</b></h1>
# stratify parameter will preserve the proportion of target as in original dataset, in the train and test datasets as well.
#
# So if your original dataset df has target/label as [0,1,2] in the ratio say, 40:30:30. That is, for every 100 datasets, you can find 40, 30 and 30 observations of target 0,1 and 2 respectively.
#
# Now when you split this original using the train_test_split(x,y,test_size=0.1,stratify=y), the methods returns train and test datasets in the ratio of 90:10. Now in each of these datasets, the target/label data proportion is preserved as 40:30:30 for the classes [0,1,2].
#
# <h1><b>random</b></h1>
# train_test_split splits arrays or matrices into random train and test subsets. That means that everytime you run it without specifying random_state, you will get a different result, this is expected behavior

# %%
xt, xn, yt, yn = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state = 2)  
#the function returns the following data and that data is assigned to the 4 variables
#the arguments X and Y are the data and target data
#test_size 0.2 is 20% as we give 0.3 it takes 30% data for testing

# %% [markdown]
# let we check the splitting

# %%
print(X.shape, xt.shape,xn.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# training the model

# %%
classifier = svm.SVC(kernel="linear") #model define

# %%
classifier.fit(xt,yt)#training process, model is ready
# Out:
# SVC(kernel='linear')

# %% [markdown]
# model evaluation

# %%
x_train_prediction = classifier.predict(xt) #predict the labels of xt using prepared model
training_data_accuracy = accuracy_score(x_train_prediction, yt) #comparing the predicted label with original labels yt and getting accuracy

# %%
print("accuracy score:",training_data_accuracy)
# Out:
# accuracy score: 0.7866449511400652

# %%
x_test_prediction = classifier.predict(xn) #predict the labels of xt using prepared model
testing_data_accuracy = accuracy_score(x_test_prediction, yn)
print("accuracy score for testin:",testing_data_accuracy)
# Out:
# accuracy score for testin: 0.7727272727272727

# %% [markdown]
# making predictive system

# %% [markdown]
# let we input to model from selecting one row from the dataset without label

# %%
df.head(12)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
input_data = (2,197,70,45,543,30.5,0.158,53) #i selected 8th index row as input it is diabetic

# %% [markdown]
# converting the data in the form as input to the model

# %%
input_array = np.asarray(input_data)
print(input_array)
# Out:
# [2.00e+00 1.97e+02 7.00e+01 4.50e+01 5.43e+02 3.05e+01 1.58e-01 5.30e+01]

# %% [markdown]
# reshape the data due to it contain only one

# %%
input_reshaped = input_array.reshape(1,-1)

# %% [markdown]
# standardised the data as we did above

# %%
st_data = s.transform(input_reshaped)
print(st_data)
# Out:
# [[-0.54791859  2.38188392  0.04624525  1.53455054  4.02192191 -0.18943689
#   -0.94794368  1.68125866]]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
prediction = classifier.predict(st_data)
if prediction == 1:
  print("the person is diabetic")
else:
  print("person can eat more sugar")
# Out:
# the person is diabetic
